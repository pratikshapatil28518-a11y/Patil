# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshapatil28518-a11y/Patil/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=(input("length of string"))
print(A)
a=input("enter first string")
b=input("enter second string")
c=a+b
print(c)

A="pratiksha"
B="patil"
C=A+B
print(C)
# Out:
# length of string25
# 25
# enter first string20
# enter second string30
# 2030
# pratikshapatil
